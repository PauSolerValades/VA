# %% [markdown]
# # Computer Vision - P3
# # First part

# %% [markdown]
# ## Delivery
#
# Up to **1 point out of 10** will be penalized if the following requirements are not fulfilled:
#
# - Implemented code should be commented.
#
# - The questions introduced in the exercises must be answered.
#
# - Add title to the figures to explain what is displayed.
#
# - Comments need to be in **English**.
#
# - The deliverable of both parts must be a file named **P3_Student1_Student2.zip** that includes:
#     - The notebook P3_Student1_Student2.ipynb completed with the solutions to the exercises and their corresponding comments.
#     - All the images used in this notebook.
#
# **Deadline (Campus Virtual): October 26th, 23:00 h**

# %% [markdown]
# ==============================================================================================
# ## Practicum 3: Image and Video Segmentation
#
# ==============================================================================================

# %% [markdown]
# The main topics of Laboratory 3 are:
#
# First part: Video Segmentation:
#
# 3.1. Segmentation of video shots with static scenes.
#
# 3.2. Background subtraction.
#
# Second part: Image Segmentation:
#
# 3.3. Segmentation of images.
#
# To successfuly complete this practicum it is necessary to understand the following theory concepts: video segmentation, background subtraction, K-means clustering, different image segmentation approaches,...
#
# The following chapters of the book “Computer Vision: Algorithms and Applicatons” from Richard Szeliski have further information about the topic:
#
# * Chapter 4: Computer Vision: Algorithms and Applications.
#
# * Chapter 5: Segmentation.

# %% [markdown]
# ## Video segmentation
#
# Given the video stored in ‘Barcelona-sequence’, which contains images acquired by a static camera, we ask you to:
# - Find the temporal segments of the video (shots). Where the scene change? (Section 3.1)
# - Extract the background images and thus, remove all the "artifacts" considered as foreground related to movement. (Section 3.2)
#
#
# Note: One of the applications of the backgroun subtraction methods is the button "remove tourists" implemented in most commercial photo cameras. For instance, Adobe uses the "Monument Mode", which automatically deletes the people going by the cameras. Today, most of videoconference tools allow to put a virtual background. Thus, they need to extract the person (the foreground) and to put it on the new virtual background.

# %% [markdown]
# ## 3.1 Segmentation of video shots
#
# Read and visualize the sequence of images "images/Barcelona-sequence".
#
# Hint: In order to read a collection of images, we wil use the function [animation.FuncAnimation](https://matplotlib.org/2.0.0/api/_as_gen/matplotlib.animation.FuncAnimation.html).
#
# Observe in the following Example, how FuncAnimation is used to read and visualize a sequence of frames. Explore the parameters of animation.FuncAnimation().

# %%
# %matplotlib inline

# %%
def visualize2(tigre_f,tigre_x,label1,label2):
    #visualize
    fig=plt.figure(figsize=(15,15))
    fig.add_subplot(1,2,1)
    plt.title(label1)
    plt.imshow(tigre_f, cmap='gray')
    plt.xticks([])
    plt.yticks([])
    fig.add_subplot(1,2,2)
    plt.title(label2)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(tigre_x, cmap='gray')

# %%
# Example
import numpy as np
import skimage
from skimage import io
import matplotlib.pyplot as plt
import matplotlib.animation as animation

ic = io.ImageCollection('images/Barcelona-sequence/*.png')
    # Reading a sequence of images from a folder
    
# %matplotlib nbagg 
    #Changing the pluggin is necessary always when visualizing a video!

fig = plt.figure()  # Create figure
im = plt.imshow(ic[0], animated=True) #Visualize the first image

def updatefig1(i):   #Updating the frame visualization
    im.set_array(ic[i*5]) #Changing the content of the canvas
    return im, #to return a tuple!

plt.show()
ani = animation.FuncAnimation(fig, updatefig1, interval=5, blit=True, frames=50, repeat= False)
plt.show()
# Out:
# /home/pau/.local/lib/python3.8/site-packages/skimage/io/manage_plugins.py:23: UserWarning: Your installed pillow version is < 7.1.0. Several security issues (CVE-2020-11538, CVE-2020-10379, CVE-2020-10994, CVE-2020-10177) have been fixed in pillow 7.1.0 or higher. We recommend to upgrade this library.
#   from .collection import imread_collection_wrapper
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# a) Each of the scenes in a video is usually called 'shot'. Find where a shot (scene) finishes and the following starts (the shot boundaries).
#
# To solve this exercise, you need to create a **temporal plot** showing a frame by frame difference measure to be defined by you, being applicable to distinguish the shots. Define a criterion to detect the boundaries of the shots and visualize it in a static plot.

# %%
# Your solution here
# 64-32 bins

from skimage.exposure import histogram
from skimage import img_as_float
import numpy as np
from skimage.color import rgba2rgb, rgb2gray


"""
Image must be rgb or rgba. això ve de la practica 2
"""
def image_histogram(image, numberOfBins):
    #Transform to rgb
    if(image.shape[2]==4):
        image_gray=rgb2gray(rgba2rgb(image))
    else:
        image_gray=rgb2gray(image)
    
    hst_r, bins_r = histogram( img_as_float(image[:,:,0]), nbins=numberOfBins)
    hst_g, bins_g = histogram( img_as_float(image[:,:,1]), nbins=numberOfBins)
    hst_b, bins_b = histogram( img_as_float(image[:,:,2]), nbins=numberOfBins)
    hst_gy, bins_gy = histogram( img_as_float(image_gray[:,:]), nbins=numberOfBins)
    
    ind = np.arange(numberOfBins)
    
    return np.array([hst_r, hst_g, hst_b])

# %%
NUM_BINS = 32
DISTANCE_THRESHOLD = 4000

# %% [markdown]
# At first, we have tried the euclidean norm to determine the difference betweeen histograms, but it detects another scene that isn't acually an scene. Instead we are going to be uding the difference and average between two histograms, in which this problem does not happen.

# %%
def distance_norm(i): #NOT USED IN ALL THE NOTEBOOK
    last_hist = image_histogram(ic[i-1], NUM_BINS)
    current_hist = image_histogram(ic[i], NUM_BINS)
    return np.linalg.norm(last_hist - current_hist)

# %%
def distance_average(i):
    last_hist = image_histogram(ic[i-1], NUM_BINS)
    current_hist = image_histogram(ic[i], NUM_BINS)
    return np.mean(np.absolute(last_hist - current_hist))

# %% [markdown]
# Despite that, if you take the median of the diference of all the histograms it gives you the best approximation in the graphic, as we show below. This happens becaus the median gives you exatly how similar are one frame with its predecesor, and it nails exatly what the problem is asking us to do. We won't be using it because we have already done it correcly with the average

# %%
def distance_median(i):
    last_hist = image_histogram(ic[i-1], NUM_BINS)
    current_hist = image_histogram(ic[i], NUM_BINS)
    return np.absloute(np.median(last_hist - current_hist))

# %% [markdown]
# Additionally, create an interactive plot executing the following code in "Example A". Substitute the bottom plot with the temporal plot showing the differences between the consecutive frames.

# %%
# Example A
# Sinusoidal plot points generation
def data_gen():
    t = data_gen.t
    cnt = 0
    while cnt < 1000:
        cnt+=1
        t += 0.05
        y = distance_median(cnt)
        # adapted the data generator to yield both sin and cos
        yield t, y


data_gen.t = 0

# %matplotlib nbagg

# create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(2,1)

# intialize a line object on the second axes for plotting
line, = ax2.plot([], [], lw=2, color='r')

ax2.set_ylim(0, DISTANCE_THRESHOLD * 1.5)
ax2.set_xlim(0, 5)
ax2.grid()

# initialize the data arrays 
xdata, ydata = [], []
def run(data):
    # update the data plot
    t, y = data
    xdata.append(t) # time = x axis
    ydata.append(y) # y axis

    # Plot image on top row
    ax1.imshow(ic[len(xdata)])
          
    # Plot sin in bottom row
    xmin, xmax = ax2.get_xlim()
    if t >= xmax:
        ax2.set_xlim(xmin, 2*xmax)
        ax2.figure.canvas.draw()
            
    # update the data of both line objects
    line.set_data(xdata, ydata)

    return line

ani = animation.FuncAnimation(fig, run, data_gen, blit=True, interval=10, repeat=False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# In case you used histograms to separate shots, use different bins to see what is the optimal size of the histogram to better separate the shots.

# %%
#we compute all the distances and sort them with the correct threshold
frames_average = [(i, distance_average(i)) for i in range(len(ic)) if(distance_average(i)>DISTANCE_THRESHOLD)]

print(frames_average)

# %% [markdown]
# b) Show the initial and final images of each shot extracted as follows:
#
# <img src="images_for_notebook/result_shot_detection.png">
#
#
# **Hint:**
# Use the previous plot to define the proper threshold value over the differences of histograms. Use the threshold to localize the initial and final frames.

# %%
# %matplotlib inline

for i in range(len(frames_average)-1):
    index = frames_average[i][0]
    next_index = frames_average[i+1][0]
    visualize2(ic[index], ic[next_index-1], "", "")

# %% [markdown]
# c) Which measure have you used in order to visually distinguish the shots in a plot? Explain your solution.

# %% [markdown]
# We used the average between the diference of the histograms. With the euclidean norm a maximum is reached in frame 191, which is not an scene transition, making us change the evaluation.

# %% [markdown]
# d) Would your video segmentation strategy be able to separate and track objects? Argue your answer.

# %% [markdown]
# No, we are not able to track objects because we cannot difere

# %% [markdown]
# e) Would your video segmentation strategy be able to capture continuous transition? Argue your answer.

# %% [markdown]
# No, because we are separating with a threshold. If the image is continous, the threshold would have to be very very thin, almost impossible

# %% [markdown]
# ## 3.2 Background subtraction
#
# Apply the background subtraction algorithm (check theory material).
#
# a) Visualize the following images for each different scene (there are 3) of the video:
#
#     1) an image belonging to the shot
#     2) the background image, and
#     3) the foreground.
#
# **Hint**: You can construct a mask obtained from the original image and the background in order to know which parts of the image form part from the foreground and recover from the original image just the foreground regions.

# %%
""" splits the scenes given the index in whish finishes"""
def scene_split(images, indexos_scenes):
    return [images[indexos_scenes[i]:indexos_scenes[i+1]] for i in range(len(indexos_scenes)-1)]

"""Recives the list of scenes and for each scene averages in time axis (t,x,y,c)"""
def backgrounds(scenes):
    return [img_as_float(np.median(scene, axis=0)) for scene in scenes]

# %%
icc = img_as_float(ic.concatenate())

indexos_scenes = [frames_average[i][0] for i in range(len(frames_average))]

scenes = scene_split(icc, indexos_scenes)

background_list = backgrounds(scenes)

for i in background_list:
    io.imshow(i)
    plt.show()

# %%
def extract_foreground(picture, threshold, background):
    picture = img_as_float(picture)
    foreground = abs(picture - background)
    #ara, com que els foreground son imprecisos (hi ha out of bounds)
    foreground = rgb2gray(foreground)
    
    mask_foreground = np.zeros(foreground.shape, dtype='uint8')
    mask_foreground[foreground < threshold] = 0
    mask_foreground[foreground >= threshold] = 1
    
    colour_foreground = picture.copy()
        
    
    colour_foreground[:,:,0][mask_foreground != 1] = 0
    colour_foreground[:,:,1][mask_foreground != 1] = 0
    colour_foreground[:,:,2][mask_foreground != 1] = 0
    
    return colour_foreground

# %%
THRESHOLDS = [0.5,0.4,0.1]

foregrounds_icc = []
for i in range(len(scenes)):
    scene_foreground = []
    for j in range(len(scenes[i])):
        scene_foreground.append(extract_foreground(scenes[i][j], THRESHOLDS[i], background_list[i]))
    foregrounds_icc.append(scene_foreground)

visualize2(scenes[0][1], foregrounds_icc[0][1], 'Original Image','Foreground')
visualize2(scenes[1][1], foregrounds_icc[1][1], 'Original Image','Foreground')
visualize2(scenes[2][1], foregrounds_icc[2][1], 'Original Image','Foreground')

# %% [markdown]
# b) What do the static background images represent?

# %% [markdown]
# Are the most commmon colour in each pixel. if a pixel (x,y) it's in all pictures mostly red, doing the median in the pixel (x,y) will result in the color which is more common that the pixel (x,y) among time.

# %% [markdown]
# c) What happens if the shots are not correctly extracted? And, what happens if you find too many shots in the video?

# %% [markdown]
# If you determine more scenes than they are, the median will be less acurate (because there will be less data) and, therefore, the background will not be as accurate as it can be.

# %% [markdown]
# d) What happens if you subtract the background image from the original one?

# %% [markdown]
# Integer overflow if you don't convert the background into a mask because the static backraound is the medioan of the colours among time, not exactly the value of the pixel and you can obtain negative values. If you make the absolute value, you obtain aproximately the foreground, the things in the image that change the most along time.

# %% [markdown]
# e) In which situations does the algorithm work and in which it does not? Do you see any additional application for this algorithm?

# %% [markdown]
# The algorithm will work it's best when the foregrounds are moving respect the background and they follow a concrete trajectory. If the trajectory steps over itself the algorithm will work more poorly, and it there is not movement in the scene, the algorithm won't detect foreground

# %% [markdown]
# f) **[OPTIONAL]**
# - Apply the algorithm to some other video that you found.

# %%
icf = io.ImageCollection('images_optional/*.jpg')
        # Reading a sequence of images from a folder
    
# %matplotlib nbagg 
    #Changing the pluggin is necessary always when visualizing a video!

fig = plt.figure()  # Create figure
im = plt.imshow(icf[0], animated=True) #Visualize the first image

def updatefig1(i):   #Updating the frame visualization
    im.set_array(icf[i*5]) #Changing the content of the canvas
    return im, #to return a tuple!

plt.show()
ani = animation.FuncAnimation(fig, updatefig1, interval=5, blit=True, frames=50, repeat= False)
plt.show()

# %%
THRESHOLD_NEW = 3750

# %%
frames_average_florencia = [(i, distance_average(i)) for i in range(len(icf)) if(distance_average(i)>THRESHOLD_NEW)]

print(frames_average)

# %%
# %matplotlib inline

for i in range(len(frames_average)-1):
    index = frames_average[i][0]
    next_index = frames_average[i+1][0]
    visualize2(icf[index], icf[next_index-1], "", "")

# %%
iccf = img_as_float(icf.concatenate())

indexos_scenes2 = [frames_average[i][0] for i in range(len(frames_average_florencia))]

scenes2 = scene_split(iccf, indexos_scenes2)

backgrounds2 = backgrounds(scenes2)

for i in backgrounds2:
    io.imshow(i)
    plt.show()

# %%
THRESHOLDS = [0.4,0.3,0.1]

foregrounds_iccf = []
for i in range(len(scenes2)):
    scene_foreground = []
    for j in range(len(scenes2[i])):
        scene_foreground.append(extract_foreground(scenes2[i][j], THRESHOLDS[i], backgrounds2[i]))
    foregrounds_iccf.append(scene_foreground)

visualize2(scenes2[0][1], foregrounds_iccf[0][1], 'Original Image','Foreground')
visualize2(scenes2[1][1], foregrounds_iccf[1][1], 'Original Image','Foreground')
visualize2(scenes2[2][1], foregrounds_iccf[2][1], 'Original Image','Foreground')

# %% [markdown]
# Com es veu, és bastant més complicat de que l'algoritme funcioni com més detall et demana l'imatge, sobretot si la càmara també es mou :(
